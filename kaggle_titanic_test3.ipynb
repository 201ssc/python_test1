# %% [markdown]
# <a href="https://colab.research.google.com/github/201ssc/python_test1/blob/main/kaggle_titanic_test3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')
sns.set(font_scale=2.5) 

import missingno as msno
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/titanic/test.csv')
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/titanic/train.csv')

# %%
df_train.head()

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# 1 Pclass

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).sum()
# Out:
#         Survived
# Sex
# female       233
# male         109

# %%
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).count()
# Out:
#         Survived
# Sex
# female       314
# male         577

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_0eeb0_row0_col0, #T_0eeb0_row0_col2, #T_0eeb0_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_0eeb0_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_0eeb0_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_0eeb0_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_0eeb0_row2_col0, #T_0eeb0_row2_col1, #T_0eeb0_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0eeb0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eeb0_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_0eeb0_row0_col0" class="data row0 col0" >81</td>
#       <td id="T_0eeb0_row0_col1" class="data row0 col1" >233</td>
#       <td id="T_0eeb0_row0_col2" class="data row0 col2" >314</td>
#     </tr>
#     <tr>
#       <th id="T_0eeb0_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_0eeb0_row1_col0" class="data row1 col0" >468</td>
#       <td id="T_0eeb0_row1_col1" class="data row1 col1" >109</td>
#       <td id="T_0eeb0_row1_col2" class="data row1 col2" >577</td>
#     </tr>
#     <tr>
#       <th id="T_0eeb0_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_0eeb0_row2_col0" class="data row2 col0" >549</td>
#       <td id="T_0eeb0_row2_col1" class="data row2 col1" >342</td>
#       <td id="T_0eeb0_row2_col2" class="data row2 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_58ee3_row0_col0, #T_58ee3_row1_col1, #T_58ee3_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_58ee3_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_58ee3_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_58ee3_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_58ee3_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_58ee3_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_58ee3_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_58ee3_row3_col0, #T_58ee3_row3_col1, #T_58ee3_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58ee3_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58ee3_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_58ee3_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_58ee3_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_58ee3_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_58ee3_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_58ee3_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_58ee3_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_58ee3_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_58ee3_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_58ee3_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_58ee3_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_58ee3_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_58ee3_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_58ee3_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_58ee3_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_58ee3_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=True).plot.bar()

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()
# sort_values : Pclass, 내림차순 (1>2>3)

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y = y_position )
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.countplot.html

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
# sns.catplot('Pclass', 'Survived', hue='Sex', data=df_train, 
#                size=6, aspect=1.5)
sns.catplot(x="Pclass", hue="Sex", col="Survived",
                data=df_train, kind="count",
                size=15, aspect=0.7);

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, 
               size=6, aspect=1.5)

# %%
sns.factorplot(x='Sex', y='Survived', col='Pclass',
              data=df_train, satureation=.5,
               size=9, aspect=1
              )

# %% [markdown]
# # Age

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %%
# Age distribution withing classes
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %% [markdown]
# 티켓을 pclass와 연관지어서 카운트 해보고 분류를 해보자!
